# %% [markdown]
# # Missing Values

# %%
import pandas as pd
import numpy as np
from pydataset import data

# %%
# Create Data
import numpy as np
data = [
    [1,'Taheera', None ,86], 
    [2,'Aelita',56,90],
    [3,'Kulan',87, None ],
    [4,'Batgerel',71,79],
    [5,'Manish', np.nan,78]
]
df = pd.DataFrame(data, columns=['Rollno','Name','Maths','English'])
df
# Out:
#    Rollno      Name  Maths  English
# 0       1   Taheera    NaN     86.0
# 1       2    Aelita   56.0     90.0
# 2       3     Kulan   87.0      NaN
# 3       4  Batgerel   71.0     79.0
# 4       5    Manish    NaN     78.0
