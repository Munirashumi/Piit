# %%
#SQL - Python Connect

# %%
# !pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# libraries (install if required)
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd
import os

# %%
# URL-encode special chars in password if any (e.g., # -> %23, @ -> %40)  #Pass@123 - Pass%40123
engine1 = create_engine("mysql+pymysql://root:piit2026@localhost:3306/piit")
print(engine1)
#setting up connection mysql with user name - piuser, pwd - Pass@123 and to database piit at port no  3306
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/piit)

# %%
engine1 = create_engine("mysql+pymysql://root:piit2026@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/piit)

# %%
# function to run the query with parameters or query
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %%
q("SELECT * FROM student")
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil     75  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %% [raw]
# select * from student;
#  select * from student where branch = "Civil";
#  select * from student where branch in ('Civil','Mechanical');
#  select * from student where name like 'R%';
#  select sum(score) from student;
# select max(score) from student;
# select min(score) from student;
# select avg(score) from student;
# select branch, avg(score) as avgscore from student group by branch;
# select branch, avg(score) as avgscore, count(*) from student group by branch;
# select * from student order by score desc;

# %%
q("SELECT * FROM student where branch ='Civil';")
# Out:
#     id              name branch  score   exam_date      remarks
# 0    4     Keith Ferrell  Civil     75  2025-06-22      Average
# 1   10  Cassidy Crawford  Civil  52.46  2025-02-25    Excellent
# 2   14  Katherine Morrow  Civil  85.95  2023-09-23  Outstanding
# 3   20   Rhonda Sullivan  Civil   88.3  2024-02-04  Outstanding
# 4   22       Emily Moore  Civil  65.21  2024-03-15  Outstanding
# 5   23   Robert Delacruz  Civil  51.92  2024-02-15         Good
# 6   27    Anna Zimmerman  Civil  83.72  2024-10-28      Average
# 7    4     Keith Ferrell  Civil     75  2025-06-22      Average
# 8   10  Cassidy Crawford  Civil  52.46  2025-02-25    Excellent
# 9   14  Katherine Morrow  Civil  85.95  2023-09-23  Outstanding
# 10  20   Rhonda Sullivan  Civil   88.3  2024-02-04  Outstanding
# 11  22       Emily Moore  Civil  65.21  2024-03-15  Outstanding
# 12  23   Robert Delacruz  Civil  51.92  2024-02-15         Good
# 13  27    Anna Zimmerman  Civil  83.72  2024-10-28      Average

# %%
q("select * from student where branch in ('Civil','Mechanical');")
# Out:
#     id              name      branch  score   exam_date      remarks
# 0    1      Rick Johnson  Mechanical  63.68  2025-03-30      Average
# 1    4     Keith Ferrell       Civil     75  2025-06-22      Average
# 2   10  Cassidy Crawford       Civil  52.46  2025-02-25    Excellent
# 3   12    Amanda Chapman  Mechanical  58.49  2025-03-04  Outstanding
# 4   14  Katherine Morrow       Civil  85.95  2023-09-23  Outstanding
# 5   20   Rhonda Sullivan       Civil   88.3  2024-02-04  Outstanding
# 6   22       Emily Moore       Civil  65.21  2024-03-15  Outstanding
# 7   23   Robert Delacruz       Civil  51.92  2024-02-15         Good
# 8   25       Danielle Le  Mechanical   91.5  2024-02-28  Outstanding
# 9   27    Anna Zimmerman       Civil  83.72  2024-10-28      Average
# 10   1      Rick Johnson  Mechanical  63.68  2025-03-30      Average
# 11   4     Keith Ferrell       Civil     75  2025-06-22      Average
# 12  10  Cassidy Crawford       Civil  52.46  2025-02-25    Excellent
# ...

# %%
import pandas as pd

# %%
df2= pd.read_sql("select * from student", engine1)
df2.shape
df2
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil     75  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %%
df2['score'].dtype
# Out:
# dtype('O')

# %%
df2['score']=pd.to_numeric(df2['score'],errors='coerce')

# %%
df2.groupby('branch')['score'].mean()
# Out:
# branch
# Civil               71.794286
# Computer Science    78.506250
# Electrical          75.497500
# Electronics         58.110000
# Mechanical          71.223333
# Name: score, dtype: float64

# %%
df2.groupby('remarks')['score'].mean()
# Out:
# remarks
# Average              71.797778
# Excellent            77.410000
# Good                 63.483333
# Needs Improvement    60.345000
# Outstanding          75.580000
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].mean()
# Out:
# branch            remarks
# Civil             Average              79.360000
#                   Excellent            52.460000
#                   Good                 51.920000
#                   Outstanding          79.820000
# Computer Science  Average              91.825000
#                   Excellent            86.080000
#                   Good                 87.880000
#                   Needs Improvement    59.996667
#                   Outstanding          90.450000
# Electrical        Excellent            93.690000
#                   Needs Improvement    63.070000
#                   Outstanding          72.615000
# Electronics       Average              60.032500
#                   Good                 50.650000
#                   Needs Improvement    59.505000
#                   Outstanding          55.090000
# Mechanical        Average              63.680000
#                   Outstanding          74.995000
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].agg(['mean','min','max'])
# Out:
#                                          mean    min    max
# branch           remarks
# Civil            Average            79.360000  75.00  83.72
#                  Excellent          52.460000  52.46  52.46
#                  Good               51.920000  51.92  51.92
#                  Outstanding        79.820000  65.21  88.30
# Computer Science Average            91.825000  88.97  94.68
#                  Excellent          86.080000  86.08  86.08
#                  Good               87.880000  87.88  87.88
#                  Needs Improvement  59.996667  51.85  65.00
#                  Outstanding        90.450000  90.45  90.45
# Electrical       Excellent          93.690000  93.69  93.69
#                  Needs Improvement  63.070000  63.07  63.07
#                  Outstanding        72.615000  70.88  74.35
# Electronics      Average            60.032500  53.81  78.04
#                  Good               50.650000  50.65  50.65
# ...
